# %% [markdown]
# # Numpy

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print(arr)
mean =  arr.mean()
print(mean)
# Out:
# [1 2 3 4 5]
# 3.0

# %%
# para poder imprimir las columnas de mi dataset

# print(dataset.columns)

# %%
import matplotlib.pyplot as plt

# Datos para el eje x e y
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Graficar la línea
plt.plot(x, y)

# Etiquetas para los ejes x e y
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

# Título del gráfico
plt.title('Gráfico de una línea')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado 'dataset' con columnas 'Year' y 'Population'
# y quieres crear un nuevo DataFrame 'X' con esas dos columnas y una columna de unos.

# Crear un DataFrame 'X' con las columnas 'Year' y 'Population'
X = dataset[["Year", "Population"]]

# Agregar una nueva columna llamada 'Ones' con valores de 1
X["Ones"] = 1

# Imprimir el DataFrame 'X' resultante
print(X)
